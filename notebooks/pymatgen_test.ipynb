# %%
from pymatgen.core import Element
for Z in range(1,50):
    elm = Element("H").from_Z(Z)
    print(elm,":", elm.oxidation_states, elm.common_oxidation_states)
# Out:
# H : (-1, 1) (-1, 1)
# He : () ()
# Li : (1,) (1,)
# Be : (2,) (2,)
# B : (1, 2, 3) (3,)
# C : (-4, -3, -2, -1, 1, 2, 3, 4) (-4, 4)
# N : (-3, -2, -1, 1, 2, 3, 4, 5) (-3, 3, 5)
# O : (-2, -1, 1, 2) (-2,)
# F : (-1,) (-1,)
# Ne : () ()
# Na : (-1, 1) (1,)
# Mg : (1, 2) (2,)
# Al : (1, 3) (3,)
# Si : (-4, -3, -2, -1, 1, 2, 3, 4) (-4, 4)
# P : (-3, -2, -1, 1, 2, 3, 4, 5) (-3, 3, 5)
# S : (-2, -1, 1, 2, 3, 4, 5, 6) (-2, 2, 4, 6)
# Cl : (-1, 1, 2, 3, 4, 5, 6, 7) (-1, 1, 3, 5, 7)
# Ar : () ()
# K : (-1, 1) (1,)
# Ca : (2,) (2,)
# Sc : (1, 2, 3) (3,)
# Ti : (-1, 2, 3, 4) (4,)
# V : (-1, 1, 2, 3, 4, 5) (5,)
# Cr : (-2, -1, 1, 2, 3, 4, 5, 6) (3, 6)
# Mn : (-3, -2, -1, 1, 2, 3, 4, 5, 6, 7) (2, 4, 7)
# Fe : (-2, -1, 1, 2, 3, 4, 5, 6) (2, 3)
# Co : (-1, 1, 2, 3, 4, 5) (2, 3)
# Ni : (-1, 1, 2, 3, 4) (2,)
# Cu : (1, 2, 3, 4) (2,)
# Zn : (1, 2) (2,)
# Ga : (1, 2, 3) (3,)
# Ge : (-4, 1, 2, 3, 4) (-4, 2, 4)
# As : (-3, 2, 3, 5) (-3, 3, 5)
# Se : (-2, 2, 4, 6) (-2, 2, 4, 6)
# ...

# %%
from pymatgen.core.ion import Ion

ion = Ion("LiCoO2")
ion.oxi_state_guesses(all_oxi_states=False)
# Out:
# ({'Li': 1.0, 'Co': 3.0, 'O': -2.0},)

# %%
from pymatgen.core.ion import Ion

ion = Ion("LiFePO4")
ion.oxi_state_guesses(all_oxi_states=False)
# Out:
# ({'Li': 1.0, 'Fe': 2.0, 'P': 5.0, 'O': -2.0},
#  {'Li': 1.0, 'Fe': 3.0, 'P': 4.0, 'O': -2.0})

# %%
from pymatgen.core.ion import Ion

ion = Ion("PbTiO3")
ion.oxi_state_guesses(all_oxi_states=False)
# Out:
# ({'Pb': 2.0, 'Ti': 4.0, 'O': -2.0}, {'Pb': 4.0, 'Ti': 2.0, 'O': -2.0})

# %%
from pymatgen.core.ion import Ion

ion = Ion("HfO2")
ion.oxi_state_guesses(all_oxi_states=False)
# Out:
# ({'Hf': 4.0, 'O': -2.0},)

# %%
from pymatgen.core.ion import Ion

ion = Ion("LiO")
ion.oxi_state_guesses(all_oxi_states=False)
# Out:
# ()

# %%
from pymatgen.core.ion import Ion

ion = Ion("LiO")
ion.oxi_state_guesses(all_oxi_states=True)
# Out:
# ({'Li': 1.0, 'O': -1.0},)

# %%
from pymatgen.core.ion import Ion

ion = Ion("LiO8")
ion.oxi_state_guesses(all_oxi_states=False)
# Out:
# ()

# %%
from pymatgen.core.ion import Ion

ion = Ion("LiO8")
ion.oxi_state_guesses(all_oxi_states=True)
# Out:
# ({'Li': 1.0, 'O': -0.125},)

# %%
from pymatgen.core.ion import Ion

ion = Ion("MnFe")
ion.oxi_state_guesses(all_oxi_states=False)
# Out:
# ()

# %%
from pymatgen.core.ion import Ion

ion = Ion("MnFe")
ion.oxi_state_guesses(all_oxi_states=True)
# Out:
# ({'Mn': 2.0, 'Fe': -2.0},
#  {'Mn': -3.0, 'Fe': 3.0},
#  {'Mn': -2.0, 'Fe': 2.0},
#  {'Mn': -1.0, 'Fe': 1.0},
#  {'Mn': 1.0, 'Fe': -1.0})
